# %%
# -*- coding: utf-8 -*-
'''
WARNING: Use this code at your own risk, scraping is against Zillow's TOC.
Zillow home listings scraper, using Selenium.  The code takes as input search 
terms that would normally be entered on the Zillow home page.  It creates 11 
variables on each home listing from the data, saves them to a data frame, 
and then writes the df to a CSV file that gets saved to your working directory.
Software requirements/info:
- This code was written using Python 3.5.
- Scraping is done with Selenium v3.0.2, which can be downloaded here: 
  http://www.seleniumhq.org/download/
- The selenium package requires a webdriver program. This code was written 
  using Chromedriver v2.25, which can be downloaded here: 
  https://sites.google.com/a/chromium.org/chromedriver/downloads
  
'''

import time
import pandas as pd
import zillow_functions as zl
from bs4 import BeautifulSoup

# Create list of search terms.
# Function zipcodes_list() creates a list of US zip codes that will be 
# passed to the scraper. For example, st = zipcodes_list(['10', '11', '606'])  
# will yield every US zip code that begins with '10', begins with "11", or 
# begins with "606" as a single list.
# I recommend using zip codes, as they seem to be the best option for catching
# as many house listings as possible. If you want to use search terms other 
# than zip codes, simply skip running zipcodes_list() function below, and add 
# a line of code to manually assign values to object st, for example:
# st = ['Chicago', 'New Haven, CT', '77005', 'Jacksonville, FL']
# Keep in mind that, for each search term, the number of listings scraped is 
# capped at 520, so in using a search term like "Chicago" the scraper would 
# end up missing most of the results.
# Param st_items can be either a list of zipcode strings, or a single zipcode 
# string.
st = zl.zipcodes_list(st_items = ["151", "152"])
print(len(st))
# Initialize the webdriver.
driver = zl.init_driver("C:/Users/Varun/chromedriver.exe")

# Go to www.zillow.com/homes
zl.navigate_to_website(driver, "http://www.zillow.com/homes")

# Click the "buy" button.
zl.click_buy_button(driver)

# Create 11 variables from the scrapped HTML data.
# These variables will make up the final output dataframe.
df = pd.DataFrame({'address' : [], 
                   'bathrooms' : [], 
                   'bedrooms' : [], 
                   'city' : [], 
                   'days_on_zillow' : [], 
                   'price' : [], 
                   'sale_type' : [], 
                   'state' : [], 
                   'sqft' : [], 
                   'url' : [], 
                   'zip' : []})

# Get total number of search terms.
numSearchTerms = len(st)

# Start the scraping.
for k in range(numSearchTerms):
    # Define search term (must be str object).
    search_term = st[k]

    # Enter search term and execute search.
    if zl.enter_search_term(driver, search_term):
        print("Entering search term number " + str(k+1) + 
              " out of " + str(numSearchTerms))
    else:
        print("Search term " + str(k+1) + 
              " failed, moving onto next search term\n***")
        continue
    
    # Check to see if any results were returned from the search.
    # If there were none, move onto the next search.
    if zl.results_test(driver):
        print("Search " + str(search_term) + 
              " returned zero results. Moving onto the next search\n***")
        continue
    
    # Pull the html for each page of search results. Zillow caps results at 
    # 20 pages, each page can contain 26 home listings, thus the cap on home 
    # listings per search is 520.
    rawdata = zl.get_html(driver)
    print(str(len(rawdata)) + " pages of listings found")
    
    # Take the extracted HTML and split it up by individual home listings.
    listings = zl.get_listings(rawdata)
    
    # For each home listing, extract the 11 variables that will populate that 
    # specific observation within the output dataframe.
    for n in range(len(listings)):
        soup = BeautifulSoup(listings[n], "lxml")
        new_obs = []
        
        # List that contains number of beds, baths, and total sqft (and 
        # sometimes price as well).
        card_info = zl.get_card_info(soup)
        
        # Street Address
        new_obs.append(zl.get_street_address(soup))
        
        # Bathrooms
        new_obs.append(zl.get_bathrooms(card_info))
        
        # Bedrooms
        new_obs.append(zl.get_bedrooms(card_info))
        
        # City
        new_obs.append(zl.get_city(soup))
        
        # Days on the Market/Zillow
        new_obs.append(zl.get_days_on_market(soup))
        
        # Price
        new_obs.append(zl.get_price(soup, card_info))
        
        # Sale Type (House for Sale, New Construction, Foreclosure, etc.)
        new_obs.append(zl.get_sale_type(soup))
        
        # Sqft
        new_obs.append(zl.get_sqft(card_info))
        
        # State
        new_obs.append(zl.get_state(soup))
        
        # URL for each house listing
        new_obs.append(zl.get_url(soup))
        
        # Zipcode
        new_obs.append(zl.get_zipcode(soup))
    
        # Append new_obs to df as a new observation
        if len(new_obs) == len(df.columns):
            df.loc[len(df.index)] = new_obs

# Close the webdriver connection.
zl.close_connection(driver)

# Write df to CSV.
columns = ['address', 'city', 'state', 'zip', 'price', 'sqft', 'bedrooms', 
           'bathrooms', 'days_on_zillow', 'sale_type', 'url']

df = df[columns]
dt = time.strftime("%Y-%m-%d") + "_" + time.strftime("%H%M%S")
filename = str(dt) + ".csv"
df.to_csv(filename, index = False)
print(filename)
# Out:
# 105
# Entering search term number 1 out of 105
# 4 pages of listings found
# 107 home listings scraped
# ***
# Entering search term number 2 out of 105
# 6 pages of listings found
# 155 home listings scraped
# ***
# Entering search term number 3 out of 105
# 3 pages of listings found
# 74 home listings scraped
# ***
# Entering search term number 4 out of 105
# 6 pages of listings found
# 137 home listings scraped
# ***
# Entering search term number 5 out of 105
# 9 pages of listings found
# 225 home listings scraped
# ***
# Entering search term number 6 out of 105
# 1 pages of listings found
# 26 home listings scraped
# ***
# Entering search term number 7 out of 105
# 2 pages of listings found
# 39 home listings scraped
# ***
# Entering search term number 8 out of 105
# 3 pages of listings found
# 59 home listings scraped
# ***
# Entering search term number 9 out of 105
# 6 pages of listings found
# 154 home listings scraped
# ***
# Entering search term number 10 out of 105
# 2 pages of listings found
# 46 home listings scraped
# ***
# Entering search term number 11 out of 105
# Search 15127 returned zero results. Moving onto the next search
# ***
# Entering search term number 12 out of 105
# 3 pages of listings found
# 69 home listings scraped
# ***
# Entering search term number 13 out of 105
# 3 pages of listings found
# 67 home listings scraped
# ***
# Entering search term number 14 out of 105
# 6 pages of listings found
# 136 home listings scraped
# ***
# Entering search term number 15 out of 105
# 2 pages of listings found
# 38 home listings scraped
# ***
# Entering search term number 16 out of 105
# Search 15134 returned zero results. Moving onto the next search
# ***
# Entering search term number 17 out of 105
# 2 pages of listings found
# 45 home listings scraped
# ***
# Entering search term number 18 out of 105
# 6 pages of listings found
# 137 home listings scraped
# ***
# Entering search term number 19 out of 105
# 4 pages of listings found
# 93 home listings scraped
# ***
# Entering search term number 20 out of 105
# 3 pages of listings found
# 69 home listings scraped
# ***
# Entering search term number 21 out of 105
# 6 pages of listings found
# 148 home listings scraped
# ***
# Entering search term number 22 out of 105
# Search 15123 returned zero results. Moving onto the next search
# ***
# Entering search term number 23 out of 105
# 1 pages of listings found
# 27 home listings scraped
# ***
# Entering search term number 24 out of 105
# 8 pages of listings found
# 202 home listings scraped
# ***
# Entering search term number 25 out of 105
# 2 pages of listings found
# 30 home listings scraped
# ***
# Entering search term number 26 out of 105
# 10 pages of listings found
# 238 home listings scraped
# ***
# Entering search term number 27 out of 105
# 2 pages of listings found
# 37 home listings scraped
# ***
# Entering search term number 28 out of 105
# 4 pages of listings found
# 99 home listings scraped
# ***
# Entering search term number 29 out of 105
# 6 pages of listings found
# 144 home listings scraped
# ***
# Entering search term number 30 out of 105
# 1 pages of listings found
# 20 home listings scraped
# ***
# Entering search term number 31 out of 105
# 4 pages of listings found
# 95 home listings scraped
# ***
# Entering search term number 32 out of 105
# 6 pages of listings found
# 149 home listings scraped
# ***
# Entering search term number 33 out of 105
# 6 pages of listings found
# 134 home listings scraped
# ***
# Entering search term number 34 out of 105
# 3 pages of listings found
# 56 home listings scraped
# ***
# Entering search term number 35 out of 105
# 7 pages of listings found
# 171 home listings scraped
# ***
# Entering search term number 36 out of 105
# 5 pages of listings found
# 126 home listings scraped
# ***
# Entering search term number 37 out of 105
# 3 pages of listings found
# 56 home listings scraped
# ***
# Entering search term number 38 out of 105
# 2 pages of listings found
# 39 home listings scraped
# ***
# Entering search term number 39 out of 105
# 2 pages of listings found
# 48 home listings scraped
# ***
# Entering search term number 40 out of 105
# 7 pages of listings found
# 158 home listings scraped
# ***
# Entering search term number 41 out of 105
# 4 pages of listings found
# 99 home listings scraped
# ***
# Entering search term number 42 out of 105
# 7 pages of listings found
# 180 home listings scraped
# ***
# Entering search term number 43 out of 105
# 2 pages of listings found
# 53 home listings scraped
# ***
# Entering search term number 44 out of 105
# 5 pages of listings found
# 111 home listings scraped
# ***
# Entering search term number 45 out of 105
# 4 pages of listings found
# 82 home listings scraped
# ***
# Entering search term number 46 out of 105
# 5 pages of listings found
# 114 home listings scraped
# ***
# Entering search term number 47 out of 105
# 4 pages of listings found
# 99 home listings scraped
# ***
# Entering search term number 48 out of 105
# 6 pages of listings found
# 154 home listings scraped
# ***
# Entering search term number 49 out of 105
# 2 pages of listings found
# 51 home listings scraped
# ***
# Entering search term number 50 out of 105
# 4 pages of listings found
# 86 home listings scraped
# ***
# Entering search term number 51 out of 105
# 10 pages of listings found
# 257 home listings scraped
# ***
# Entering search term number 52 out of 105
# 2 pages of listings found
# 50 home listings scraped
# ***
# Entering search term number 53 out of 105
# 2 pages of listings found
# 37 home listings scraped
# ***
# Entering search term number 54 out of 105
# 2 pages of listings found
# 50 home listings scraped
# ***
# Entering search term number 55 out of 105
# 1 pages of listings found
# 6 home listings scraped
# ***
# Entering search term number 56 out of 105
# 4 pages of listings found
# 92 home listings scraped
# ***
# Entering search term number 57 out of 105
# 8 pages of listings found
# 197 home listings scraped
# ***
# Entering search term number 58 out of 105
# 4 pages of listings found
# 83 home listings scraped
# ***
# Entering search term number 59 out of 105
# 4 pages of listings found
# 84 home listings scraped
# ***
# Entering search term number 60 out of 105
# Search 15230 returned zero results. Moving onto the next search
# ***
# Entering search term number 61 out of 105
# Search 15231 returned zero results. Moving onto the next search
# ***
# Entering search term number 62 out of 105
# 2 pages of listings found
# 39 home listings scraped
# ***
# Entering search term number 63 out of 105
# 2 pages of listings found
# 29 home listings scraped
# ***
# Entering search term number 64 out of 105
# 3 pages of listings found
# 75 home listings scraped
# ***
# Entering search term number 65 out of 105
# 17 pages of listings found
# 441 home listings scraped
# ***
# Entering search term number 66 out of 105
# 6 pages of listings found
# 132 home listings scraped
# ***
# Entering search term number 67 out of 105
# 7 pages of listings found
# 180 home listings scraped
# ***
# Entering search term number 68 out of 105
# 8 pages of listings found
# 199 home listings scraped
# ***
# Entering search term number 69 out of 105
# 7 pages of listings found
# 167 home listings scraped
# ***
# Entering search term number 70 out of 105
# Search 15240 returned zero results. Moving onto the next search
# ***
# Entering search term number 71 out of 105
# 9 pages of listings found
# 231 home listings scraped
# ***
# Entering search term number 72 out of 105
# Search 15242 returned zero results. Moving onto the next search
# ***
# Entering search term number 73 out of 105
# 4 pages of listings found
# 92 home listings scraped
# ***
# Entering search term number 74 out of 105
# Search 15244 returned zero results. Moving onto the next search
# ***
# Entering search term number 75 out of 105
# Search 15250 returned zero results. Moving onto the next search
# ***
# Entering search term number 76 out of 105
# Search 15251 returned zero results. Moving onto the next search
# ***
# Entering search term number 77 out of 105
# Search 15252 returned zero results. Moving onto the next search
# ***
# Entering search term number 78 out of 105
# Search 15253 returned zero results. Moving onto the next search
# ***
# Entering search term number 79 out of 105
# Search 15254 returned zero results. Moving onto the next search
# ***
# Entering search term number 80 out of 105
# Search 15255 returned zero results. Moving onto the next search
# ***
# Entering search term number 81 out of 105
# Search 15257 returned zero results. Moving onto the next search
# ***
# Entering search term number 82 out of 105
# Search 15258 returned zero results. Moving onto the next search
# ***
# Entering search term number 83 out of 105
# Search 15259 returned zero results. Moving onto the next search
# ***
# Entering search term number 84 out of 105
# Search 15260 returned zero results. Moving onto the next search
# ***
# Entering search term number 85 out of 105
# Search 15261 returned zero results. Moving onto the next search
# ***
# Entering search term number 86 out of 105
# Search 15262 returned zero results. Moving onto the next search
# ***
# Entering search term number 87 out of 105
# Search 15264 returned zero results. Moving onto the next search
# ***
# Entering search term number 88 out of 105
# Search 15265 returned zero results. Moving onto the next search
# ***
# Entering search term number 89 out of 105
# Search 15267 returned zero results. Moving onto the next search
# ***
# Entering search term number 90 out of 105
# Search 15268 returned zero results. Moving onto the next search
# ***
# Entering search term number 91 out of 105
# Search 15270 returned zero results. Moving onto the next search
# ***
# Entering search term number 92 out of 105
# Search 15272 returned zero results. Moving onto the next search
# ***
# Entering search term number 93 out of 105
# Search 15274 returned zero results. Moving onto the next search
# ***
# Entering search term number 94 out of 105
# Search 15275 returned zero results. Moving onto the next search
# ***
# Entering search term number 95 out of 105
# Search 15276 returned zero results. Moving onto the next search
# ***
# Entering search term number 96 out of 105
# Search 15277 returned zero results. Moving onto the next search
# ***
# Entering search term number 97 out of 105
# Search 15278 returned zero results. Moving onto the next search
# ***
# Entering search term number 98 out of 105
# Search 15279 returned zero results. Moving onto the next search
# ***
# Entering search term number 99 out of 105
# Search 15281 returned zero results. Moving onto the next search
# ***
# Entering search term number 100 out of 105
# Search 15282 returned zero results. Moving onto the next search
# ***
# Entering search term number 101 out of 105
# Search 15283 returned zero results. Moving onto the next search
# ***
# Entering search term number 102 out of 105
# Search 15286 returned zero results. Moving onto the next search
# ***
# Entering search term number 103 out of 105
# Search 15289 returned zero results. Moving onto the next search
# ***
# Entering search term number 104 out of 105
# Search 15290 returned zero results. Moving onto the next search
# ***
# Entering search term number 105 out of 105
# Search 15295 returned zero results. Moving onto the next search
# ***
# 2017-04-25_201909.csv
